# %%
# Q1: What is statistics, and why is it important?
# A1: Statistics is the science of collecting, analyzing, interpreting, and presenting data.
#     It is important because it helps in decision-making based on data insights.

# Q2: What are the two main types of statistics?
# A2: Descriptive statistics and Inferential statistics.

# Q3: What are descriptive statistics?
# A3: Descriptive statistics summarize and describe the features of a dataset (e.g., mean, median, mode, standard deviation).

# Q4: What is inferential statistics?
# A4: Inferential statistics use sample data to make generalizations or predictions about a population.

# Q5: What is sampling in statistics?
# A5: Sampling is the process of selecting a subset of individuals from a population to estimate characteristics of the whole population.

# Q6: What are the different types of sampling methods?
# A6: Types include:
#     1. Simple Random Sampling
#     2. Systematic Sampling
#     3. Stratified Sampling
#     4. Cluster Sampling
#     5. Convenience Sampling

# Q7: What is the difference between random and non-random sampling?
# A7: Random sampling ensures every member has an equal chance of selection; non-random sampling does not, which may introduce bias.

# Q8: Define and give examples of qualitative and quantitative data
# A8: Qualitative (categorical): Colors, gender, nationality.
#     Quantitative (numerical): Age, salary, height.

# Q9: What are the different types of data in statistics?
# A9: Types include:
#     1. Nominal
#     2. Ordinal
#     3. Interval
#     4. Ratio

# Q10: Explain nominal, ordinal, interval, and ratio levels of measurement
# A10:
#   - Nominal: Categories with no order (e.g., gender)
#   - Ordinal: Categories with order (e.g., education level)
#   - Interval: Ordered, equal intervals, no true zero (e.g., temperature in Celsius)
#   - Ratio: Ordered, equal intervals, true zero (e.g., weight, height)

# Q11: What is the measure of central tendency?
# A11: It refers to values that represent the center or average of a dataset (mean, median, mode).

# Q12: Define mean, median, and mode
# A12:
#   - Mean: Average of all values
#   - Median: Middle value when sorted
#   - Mode: Most frequent value

# Q13: What is the significance of the measure of central tendency?
# A13: It provides a single value that summarizes an entire dataset and helps understand the general trend.

# Q14: What is variance, and how is it calculated?
# A14: Variance measures the average squared deviation from the mean.
#      Formula: Var(X) = Σ(x - mean)² / N

# Q15: What is standard deviation, and why is it important?
# A15: Standard deviation is the square root of variance. It indicates how spread out the values are around the mean.

# Q16: Define and explain the term range in statistics
# A16: Range is the difference between the maximum and minimum values in a dataset.

# Q17: What is the difference between variance and standard deviation?
# A17: Variance is the average squared deviation; standard deviation is the square root of variance.
#      SD is in the same unit as the data, variance is not.

# Q18: What is skewness in a dataset?
# A18: Skewness measures the asymmetry of the distribution of values.

# Q19: What does it mean if a dataset is positively or negatively skewed?
# A19:
#   - Positive skew: Tail on the right, mean > median
#   - Negative skew: Tail on the left, mean < median

# Q20: Define and explain kurtosis
# A20: Kurtosis measures the "tailedness" of the distribution.
#      High kurtosis = heavy tails; low kurtosis = light tails.

# Q21: What is the purpose of covariance?
# A21: Covariance indicates the direction of the linear relationship between two variables.

# Q22: What does correlation measure in statistics?
# A22: Correlation measures the strength and direction of the linear relationship between variables (ranges from -1 to 1).

# Q23: What is the difference between covariance and correlation?
# A23:
#   - Covariance indicates direction but not strength (unit-dependent)
#   - Correlation is scaled (unitless), and shows both direction and strength

# Q24: What are some real-world applications of statistics?
# A24: Applications include:
#   - Healthcare (clinical trials)
#   - Business (market analysis)
#   - Sports (performance metrics)
#   - Government (census)
#   - Education (test scoring and analysis)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
import pandas as pd
import numpy as np

data = [1,2,3,4,5]
df = pd.DataFrame(data)
df.mean()
# Out:
# 0    3.0
# dtype: float64

# %%
df.median()
# Out:
# 0    3.0
# dtype: float64

# %%
df.mode()
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
#2

np.var(df)
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:4006: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# 0    2.0
# dtype: float64

# %%
np.std(df)
# Out:
# 0    1.414214
# dtype: float64

# %%
#3
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#nominal(Gender) - ordinal(Rank)- interval(temp) - ratio types(Age)
#3
import pandas as pd
df1 = pd.DataFrame({'Rank': [1,2,3,4], 'Gender': ['F','M','M','M'],'Age':[23,44,55,66],'temp':[23.3,33,44,5]})
df1
# Out:
#    Rank Gender  Age  temp
# 0     1      F   23  23.3
# 1     2      M   44  33.0
# 2     3      M   55  44.0
# 3     4      M   66   5.0

# %%
#4sampling
sample = df.sample(n=2,random_state=42)
print(sample)

#stratified
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.5, stratify=df['sex'], random_state=42)
print(test)

#systematic
k = 2
systematic_sample = df.iloc[::k]
print(systematic_sample)
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 24       19.82  3.18  Male     No  Sat  Dinner     2
# 6         8.77  2.00  Male     No  Sun  Dinner     2
#      total_bill   tip     sex smoker   day    time  size
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2
# 163       13.81  2.00    Male     No   Sun  Dinner     2
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 87        18.28  4.00    Male     No  Thur   Lunch     2
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# 118       12.43  1.80  Female     No  Thur   Lunch     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
#
# [122 rows x 7 columns]
#      total_bill   tip     sex smoker  day    time  size
# ...

# %%
#5
df_numeric = df.select_dtypes(exclude = ['object','category'])
range_vals = df_numeric.max() - df_numeric.min()
print(range_vals)
# Out:
# total_bill    47.74
# tip            9.00
# size           5.00
# dtype: float64

# %%
#6
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["size"], bins = 10, color = "skyblue")
plt.title("skweness of hist")
plt.xlabel("value")
plt.ylabel("freq of size")
plt.grid(True)
plt.show()

# %%
#7
import scipy.stats as stats

skew = stats.skew(df_numeric)
kurtosis = stats.kurtosis(df_numeric)

print("Skewness:", skew)
print("Kurtosis:", kurtosis)
# Out:
# Skewness: [1.12623463 1.45642669 1.43896538]
# Kurtosis: [1.16916813 3.54955199 1.67192763]

# %%
#8

import matplotlib.pyplot as plt

# Positively skewed
positive_skew = np.random.exponential(scale=2, size=1000)
# Negatively skewed (flip of exponential)
negative_skew = -np.random.exponential(scale=2, size=1000)

plt.hist(positive_skew, bins=30, alpha=0.6, label="Positive Skew")
plt.hist(negative_skew, bins=30, alpha=0.6, label="Negative Skew")
plt.legend()
plt.title("Positive and Negative Skewness")
plt.show()

# %%
#9
# Two datasets
x = np.random.rand(100)
y = 2 * x + np.random.normal(0, 0.1, 100)

# Covariance
cov_matrix = np.cov(x, y)
print("Covariance matrix:\n", cov_matrix)
print("Covariance between x and y:", cov_matrix[0, 1])
# Out:
# Covariance matrix:
#  [[0.08628511 0.17102909]
#  [0.17102909 0.34828548]]
# Covariance between x and y: 0.1710290858194687

# %%
#10
cor = np.corrcoef(x, y)

print("Covariance matrix:\n", cor)
print("Covariance between x and y:", cor[0, 1])
# Out:
# Covariance matrix:
#  [[1.         0.98658465]
#  [0.98658465 1.        ]]
# Covariance between x and y: 0.9865846535417834

# %%
#11

import matplotlib.pyplot as plt

plt.scatter(df["tip"],df["size"])
plt.title("scatter plot")
plt.xlabel("x label")
plt.ylabel("y label")
plt.show()

# %%
#12
import pandas as pd
import numpy as np

# Create dataset
population = pd.DataFrame({'ID': range(1, 101), 'Value': np.random.randint(10, 100, 100)})

# Simple Random Sampling (sample 10)
simple_sample = population.sample(n=10, random_state=42)

# Systematic Sampling (every 10th element)
k = 10
start = np.random.randint(0, k)
systematic_sample = population.iloc[start::k][:10]

print("Simple Random Sampling:\n", simple_sample)
print("\nSystematic Sampling:\n", systematic_sample)
# Out:
# Simple Random Sampling:
#      ID  Value
# 83  84     45
# 53  54     66
# 70  71     18
# 45  46     18
# 44  45     17
# 39  40     69
# 22  23     66
# 80  81     69
# 10  11     18
# 0    1     87
#
# Systematic Sampling:
#      ID  Value
# 8    9     36
# 18  19     84
# 28  29     74
# 38  39     80
# 48  49     27
# 58  59     39
# 68  69     18
# 78  79     28
# 88  89     27
# 98  99     71

# %%
#13

import pandas as pd

# Raw data with class labels
data = pd.DataFrame({
    'Score': [12, 15, 18, 22, 27, 33, 36, 38, 40],
    'Group': ['10-20', '10-20', '10-20', '20-30', '20-30', '30-40', '30-40', '30-40', '30-40']
})

# Group by class intervals and calculate mean
grouped_mean = data.groupby('Group')['Score'].mean()
print("Mean per group:\n", grouped_mean)

grouped_mode = data.groupby('Group')['Score'].apply(lambda x: x.mode())
print("Mode per group:\n", grouped_mode)

grouped_med = data.groupby('Group')['Score'].median()
print("Mean per group:\n", grouped_med)
# Out:
# Mean per group:
#  Group
# 10-20    15.00
# 20-30    24.50
# 30-40    36.75
# Name: Score, dtype: float64
# Mode per group:
#  Group
# 10-20  0    12
#        1    15
#        2    18
# 20-30  0    22
#        1    27
# 30-40  0    33
#        1    36
#        2    38
#        3    40
# Name: Score, dtype: int64
# Mean per group:
#  Group
# 10-20    15.0
# 20-30    24.5
# 30-40    37.0
# Name: Score, dtype: float64

# %%
#14

import numpy as np
import pandas as pd
from scipy import stats

# 1. Simulate data (e.g., exam scores)
np.random.seed(42)
data = np.random.normal(loc=70, scale=10, size=100)  # mean=70, std=10, n=100

# Convert to DataFrame
df = pd.DataFrame(data, columns=['Score'])

# 2. Central Tendency
mean = df['Score'].mean()
median = df['Score'].median()
mode = df['Score'].mode().values.tolist()

# 3. Dispersion
data_range = df['Score'].max() - df['Score'].min()
variance = df['Score'].var()
std_dev = df['Score'].std()

# 4. Display results
print("Central Tendency:")
print(f"  Mean   : {mean:.2f}")
print(f"  Median : {median:.2f}")
print(f"  Mode   : {mode}")

print("\nDispersion:")
print(f"  Range      : {data_range:.2f}")
print(f"  Variance   : {variance:.2f}")
print(f"  Std Dev    : {std_dev:.2f}")
# Out:
# Central Tendency:
#   Mean   : 68.96
#   Median : 68.73
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = sns.load_dataset('tips')
df1 = df.select_dtypes(exclude = ['object','category'])

# %%
#15
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# Simulate dataset
np.random.seed(1)
data = np.random.normal(loc=50, scale=15, size=100)
dfp = pd.DataFrame({'Value': data})

# Descriptive statistics
print("Descriptive Statistics:\n", dfp.describe())
# Out:
# Descriptive Statistics:
#              Value
# count  100.000000
# mean    50.908743
# std     13.344232
# min     15.476920
# 25%     40.792737
# 50%     50.961109
# 75%     59.561155
# max     82.783631

# %%
#16
sns.boxplot(x=df['size'])
plt.title("Boxplot of Value")
plt.show()

# %%
#17
Q1 = df['size'].quantile(0.25)
Q3 = df['size'].quantile(0.75)
IQR = Q3 - Q1
print("Interquartile Range (IQR):", IQR)
# Out:
# Interquartile Range (IQR): 1.0

# %%
#18
df['Zscore'] = (df['size'] - df['size'].mean()) / df['size'].std()
print(df.head())

# Explanation:
print("\nZ-score normalization transforms data to have mean = 0 and std = 1. Useful for comparisons across different scales.")
# Out:
#    total_bill   tip     sex smoker  day    time  size    Zscore
# 0       16.99  1.01  Female     No  Sun  Dinner     2 -0.598961
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.452453
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.452453
# 3       23.68  3.31    Male     No  Sun  Dinner     2 -0.598961
# 4       24.59  3.61  Female     No  Sun  Dinner     4  1.503867
#
# Z-score normalization transforms data to have mean = 0 and std = 1. Useful for comparisons across different scales.

# %%
#19
data2 = np.random.normal(loc=55, scale=25, size=100)
std1 = np.std(df1)
std2 = np.std(data2)

print(f"Standard Deviation of Dataset 1: {std1}")
print(f"Standard Deviation of Dataset 2: {std2}")
# Out:
# Standard Deviation of Dataset 1: total_bill    8.884151
# tip           1.380800
# size          0.949149
# dtype: float64
# Standard Deviation of Dataset 2: 25.123412832066062

# %%
#20
import seaborn as sns
cov = df1.cov()
sns.heatmap(cov, color = "skyblue", annot = True)
plt.show()

# %%
#21
import seaborn as sns
corrm = df1.corr()
sns.heatmap(corrm, color = "blue", annot = True)
plt.show()

# %%
#22
import numpy as np
df1 = df.select_dtypes(exclude = ['object','category'])
variance = np.var(df1)
std_dev = np.std(df1)
print(f"Variance: {variance}, Standard Deviation: {std_dev}")
# Out:
# Variance: total_bill    78.928131
# tip            1.906609
# size           0.900883
# dtype: float64, Standard Deviation: total_bill    8.884151
# tip           1.380800
# size          0.949149
# dtype: float64
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:4006: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:3800: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
#23
sns.histplot(df['total_bill'], kde=True)
skew = stats.skew(data)
kurt = stats.kurtosis(data)
print(f"Skewness: {skew:.2f}, Kurtosis: {kurt:.2f}")
# Out:
# Skewness: -0.18, Kurtosis: -0.16

# %%
#24
print(df.columns)
df = df[['tip', 'size']].dropna()

pearson_corr, _ = stats.pearsonr(df["tip"], df['size'])
spearman_corr, _ = stats.spearmanr(df['tip'], df['size'])

print(f"Pearson Correlation: {pearson_corr:.2f}")
print(f"Spearman Correlation: {spearman_corr:.2f}")
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# Pearson Correlation: 0.49
# Spearman Correlation: 0.47
